# %% [markdown]
# # 🚚 **Entregables**
#
# **No olvide duplicar esta notebook para poder editar: File->Save a copy in Drive**
#
# En este laboratorio, no es necesario redactar un informe en un documento separado. Por favor, complete todas las actividades requeridas dentro de esta notebook de Google Colab. Recuerde que una notebook le permite ingresar elementos de texto de manera similar a un procesador de documentos. Una vez finalizadas las actividades propuestas, deberá entregar lo siguiente en la plataforma:
#
# 1. Un archivo PDF generado en Google Colab desde el menú "Archivo" -> "Imprimir".
#
# 2. El enlace público de Google Colab. Para ello, vaya al botón de compartir y cambie la configuración de compartición a "Cualquier persona con el enlace".

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Predicción de pérdida de clientes en Empresas de Servicios de Telecomunicaciones (Churn)
#
# Reducir las salidas y [deserciones de clientes](https://www.bain.com/insights/breaking-the-back-of-customer-churn/) se ha convertido en una alta prioridad para la mayoría de los proveedores de servicios de comunicaciones a medida que los mercados maduran y la competencia se intensifica.
#
#
#
#
# En este documento usaremos una base de datos de una empresa de telecomunicaciones anónima [disponibilizada por IBM](https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv).
#
# El principal objetivo es crear un model de aprendizaje automático basado Regresión Logística (similar al propuesto [aquí con SVM](https://github.com/mmcuri/ds_handson/blob/master/Telecom_Churn_Prediction.ipynb)) para predecir la pérdida o salida de clientes en una empresa de telecomunicaciones.

# %% [markdown]
# ## Librerías
#
# Importamos varias bibliotecas y módulos útiles para el análisis de datos y el aprendizaje automático en Python. A continuación se describe cada uno de ellos:
#
# - `pandas as pd`: Importa la biblioteca Pandas y la renombra como "pd". Pandas es una biblioteca popular utilizada para la manipulación y análisis de datos en Python.
#
# - `numpy as np`: Importa la biblioteca NumPy y la renombra como "np". NumPy es una biblioteca de Python utilizada para realizar operaciones matemáticas en matrices y vectores.
#
# - `matplotlib.pyplot as plt`: Importa la biblioteca Matplotlib y el módulo pyplot y lo renombra como "plt". Matplotlib es una biblioteca utilizada para la visualización de datos en Python.
#
# - `from sklearn.metrics import classification_report`: Importa la función classification_report desde el módulo metrics de la biblioteca scikit-learn. classification_report es una función que calcula y muestra un informe de clasificación detallado para un modelo de clasificación.
#
# - `from sklearn.metrics import confusion_matrix`: Importa la función confusion_matrix desde el módulo metrics de la biblioteca scikit-learn. confusion_matrix es una función que calcula y muestra la matriz de confusión para un modelo de clasificación.
#
# - `from sklearn.metrics import accuracy_score`: Importa la función accuracy_score desde el módulo metrics de la biblioteca scikit-learn. accuracy_score es una función que calcula y muestra la precisión de un modelo de clasificación.
#
# - `from sklearn.metrics import roc_auc_score`: Importa la función roc_auc_score desde el módulo metrics de la biblioteca scikit-learn. roc_auc_score es una función que calcula el área bajo la curva ROC (AUC) para un modelo de clasificación.
#
# - `from sklearn.preprocessing import StandardScaler, LabelEncoder`: Importa las clases StandardScaler y LabelEncoder desde el módulo preprocessing de la biblioteca scikit-learn. StandardScaler es una clase utilizada para estandarizar los datos y LabelEncoder es una clase utilizada para codificar las etiquetas de clase en números enteros.
#
# - `from sklearn.model_selection import train_test_split`: Importa la función train_test_split desde el módulo model_selection de la biblioteca scikit-learn. train_test_split es una función que divide los datos en conjuntos de entrenamiento y prueba para su uso en el modelado predictivo.
#
# En resumen, este código importa varias bibliotecas y módulos que son útiles para el análisis de datos y el aprendizaje automático en Python.

# %%
# importing libraries
import pandas as pd #excel sofisticado
import numpy as np #matlab
import matplotlib.pyplot as plt #plots
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Base de datos
#
# Este conjunto de datos contiene un total de 7043 clientes y 21 características de los mismos. De las entradas, 5174 son clientes activos y 1869 son clientes que la empresa ha perdido. Observe que el conjunto de datos está desbalanceado pues por cada cliente perdido existe casi 3 clientes activos. La variable de salida para nuestro modelo de machine learning será `Churn`.

# %%
# importamos dataset
DATA_PATH = "https://raw.githubusercontent.com/mtgca/datasets_public/main/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(DATA_PATH)
#print(df)
# vemos las primeras 5 filas
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### *Detalles de la base de datos*
#
# *	`customerID` - Custumer unique identifier
# *	`gender` - Customer gender - ['Female' 'Male']
# *	`SeniorCitizen` - Elderly or retired person, a senior citizen is someone who has at least attained the age of 60 of 65 years
# *	`Partner` - - ['No' 'Yes']
# *	`Dependents` - If customer has dependents - ['No' 'Yes']
# *	`Tenure` - Customer lifespan (in months)
# *	`PhoneService` - - ['No' 'Yes']
# *	`MultipleLines` - - ['No' 'No phone service' 'Yes']
# *	`InternetService` - - ['No' 'No internet service' 'Yes']
# *	`OnlineSecurity` - - ['No' 'No internet service' 'Yes']
# *	`OnlineBackup` - - ['No' 'No internet service' 'Yes']
# *	`DeviceProtection` - - ['No' 'No internet service' 'Yes']
# *	`TechSupport` - - ['No' 'No internet service' 'Yes']
# *	`StreamingTV` - - ['No' 'No internet service' 'Yes']
# *	`StreamingMovies` -  - ['No' 'No internet service' 'Yes']
# *	`Contract` - Type of contract - ['Month-to-month' 'One year' 'Two year']
# *	`PaperlessBilling` - - ['No' 'Yes']
# *	`PaymentMethod` - payment method - ['Bank transfer (automatic)', 'Credit card (automatic)', 'Electronic check', 'Mailed check']
# *	`MonthlyCharges` - Monthly Recurring Charges
# *	`TotalCharges` - Life time value
# *	`Churn` - Churn value, the targer vector - ['No' 'Yes']

# %% [markdown]
# ### *Limpieza del Dataset*
#
# El código presenta una serie de operaciones de preprocesamiento de datos en una base de datos que contiene información sobre clientes de una compañía, incluyendo su género, edad, servicios contratados, pagos realizados, entre otros.
#
# En primer lugar, se define la función get_df_size para imprimir el número de atributos y entradas de la base de datos.
#
# Luego, se reemplazan los valores en blanco por NaN para facilitar el manejo de valores faltantes en la base de datos.
#
# A continuación, se reemplazan los valores faltantes en la columna 'TotalCharges' por la mediana de esa columna y se convierte esa columna al tipo numérico.
#
# Después, se elimina la columna 'customerID' ya que no es una característica relevante.
#
# A continuación, se codifican las características binarias en 0's y 1's usando LabelEncoder y se imprimen las categorías correspondientes a cada una de estas características.

# %%
def get_df_size(df, header='Dataset dimensions'):
  print(header,
        '\n# Attributes: ', df.shape[1],
        '\n# Entries: ', df.shape[0],'\n')

get_df_size(df)

#df.info()

# reemplaza valores en blanco por NaN
df_clean = df.replace(r'^\s*$', np.nan, regex=True)

# Convert 'TotalCharges' to numeric before calculating the median.
# errors='coerce' will handle any non-numeric values by setting them to NaN.
df_clean['TotalCharges'] = pd.to_numeric(df_clean['TotalCharges'], errors='coerce')

# reemplaza valores faltantes en TotalCharges por la mediana de TotalCharges.
total_charges_median = df_clean.TotalCharges.median()
df_clean['TotalCharges'].fillna(total_charges_median, inplace=True)
df_clean['TotalCharges'] = df_clean['TotalCharges'].apply(pd.to_numeric)

#CustomerID lo retiramos porque no es una característica
df_clean = df_clean.drop('customerID', axis=1)
df_clean.describe()

print("Churn No Instances: ", df_clean[df_clean['Churn'] == 'No'].shape[0])
print("Churn Yes Instances: ", df_clean[df_clean['Churn'] == 'Yes'].shape[0])

binary_feat = df_clean.nunique()[df_clean.nunique() == 2].keys().tolist()
numeric_feat = [col for col in df_clean.select_dtypes(['float','int']).columns.tolist() if col not in binary_feat]
categorical_feat = [ col for col in df_clean.select_dtypes('object').columns.to_list() if col not in binary_feat + numeric_feat ]
df_proc = df_clean.copy()
#Etiquetas para características binarias
le = LabelEncoder()
for i in binary_feat:
  df_proc[i] = le.fit_transform(df_proc[i])
  print(i, '\n', np.unique(df_proc[i].values))
#Dummy variables
df_proc = pd.get_dummies(df_proc, columns=categorical_feat)
get_df_size(df, header='Original dataset:')
get_df_size(df_proc, header='Processed dataset:')
df_proc.head()
# Out:
# Dataset dimensions
# # Attributes:  21
# # Entries:  7043
#
# Churn No Instances:  5174
# Churn Yes Instances:  1869
# gender
#  [0 1]
# SeniorCitizen
#  [0 1]
# Partner
#  [0 1]
# Dependents
#  [0 1]
# PhoneService
#  [0 1]
# PaperlessBilling
#  [0 1]
# Churn
#  [0 1]
# Original dataset:
# # Attributes:  21
# # Entries:  7043
#
# Processed dataset:
# # Attributes:  41
# # Entries:  7043
# C:\Users\JeffDRK\AppData\Local\Temp\ipykernel_33276\2470922283.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['TotalCharges'].fillna(total_charges_median, inplace=True)
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# 0                 1           29.85         29.85      0  ...
# 1                 0           56.95       1889.50      0  ...
# 2                 1           53.85        108.15      1  ...
# 3                 0           42.30       1840.75      0  ...
# 4                 1           70.70        151.65      1  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# 1                True                                False
# 2                True                                False
# 3                True                                False
# 4                True                                False
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 0              False                                    False
# 1              False                                    False
# 2              False                                    False
# 3              False                                     True
# 4              False                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 41 columns]

# %% [markdown]
# ### *División en conjunto de entrenamiento y test*
#
# En el código, se divide el conjunto de datos df_proc en características y variable objetivo X e y, respectivamente. Luego, se realiza una división de los datos en conjuntos de entrenamiento y prueba utilizando la función train_test_split de scikit-learn. Los conjuntos de entrenamiento y prueba se almacenan en X_train, X_test, y_train y y_test. La división se realiza de manera estratificada para asegurar que la proporción de instancias positivas y negativas en la variable objetivo se mantenga en ambos conjuntos. Se utiliza una proporción de 80/20 para los conjuntos de entrenamiento y prueba, respectivamente, y se fija una semilla aleatoria (random_state) en 42 para asegurar que los resultados sean reproducibles.

# %%
# dividimos df_proc en características y salida
X=df_proc.drop('Churn', axis=1)
y=df_proc['Churn']

# Dividimos el conjunto de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# ### *Balanceo de datos*
#
# Este código realiza el submuestreo (undersampling) de un conjunto de datos desbalanceado en términos de la variable objetivo. El submuestreo se utiliza para abordar el problema del desequilibrio de clases en el conjunto de datos, donde una o varias clases tienen muchas menos observaciones que las otras clases. En este caso, el modelo de aprendizaje automático puede estar sesgado hacia la clase mayoritaria, lo que puede resultar en un rendimiento deficiente en la clasificación de la clase minoritaria.
#
# El submuestreo implica reducir el número de observaciones en la clase mayoritaria para equilibrar la distribución de las clases en el conjunto de datos. Esto puede mejorar el rendimiento del modelo en la clasificación de la clase minoritaria y reducir el sesgo hacia la clase mayoritaria.
#
# La biblioteca imblearn se utiliza para realizar el submuestreo, y en este caso se importa la clase RandomUnderSampler. El objeto RandomUnderSampler se inicializa con random_state=1, lo que garantiza que los resultados serán reproducibles.
#
# Luego, el submuestreo se realiza en el conjunto de entrenamiento (X_train, y_train) mediante el método fit_resample del objeto rus. Los datos submuestreados se almacenan en X_train_rus y y_train_rus.
#
# Para evaluar el efecto del submuestreo, se utiliza la función get_df_size, que devuelve el tamaño del conjunto de datos. Primero se imprime el tamaño del conjunto de entrenamiento original (X_train, y_train) antes del submuestreo, y luego se imprime el tamaño del conjunto submuestreado (X_train_rus, y_train_rus) después de aplicar el submuestreo.
#
# Finalmente, se utiliza la función np.unique para verificar que las categorías de la variable objetivo (y_train_rus) estén balanceadas. La función devuelve una tupla que contiene las categorías únicas y el número de instancias en cada categoría. Al utilizar return_counts=True, se garantiza que se devuelvan los recuentos de las categorías.

# %%
# submuestreo -> under sampling
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=1)
X_train_undersampled, y_train_undersampled = rus.fit_resample(X_train, y_train)
get_df_size(X_train, header='Before balancing:')
get_df_size(X_train_undersampled, header='After balancing:')

# verificamos que las categorias estén balanceadas
np.unique(y_train_undersampled, return_counts=True)
# Out:
# Before balancing:
# # Attributes:  40
# # Entries:  5634
#
# After balancing:
# # Attributes:  40
# # Entries:  2990
# (array([0, 1]), array([1495, 1495]))

# %% [markdown]
# ## Modelo de Machine Learning
#
# Este código construye un modelo de regresión logística para un conjunto de datos y lo evalúa en un conjunto de datos de prueba y de entrenamiento.
#
# Primero, se define una tubería (pipeline) que encadena tres pasos:
#
# PolynomialFeatures(degree=2): Crea una matriz de características polinómicas de grado 2 a partir de las características originales.
# StandardScaler(): Estandariza las características.
# LogisticRegression(max_iter=20000, penalty='l2', C=1/lambda_value): Ajusta un modelo de regresión logística a los datos, utilizando una regularización L2 (Ridge) y un parámetro de regularización C inversamente proporcional a lambda_value.
# Luego, el modelo se entrena en un conjunto de datos de entrenamiento (X_train_undersampled e y_train_undersampled) utilizando el método fit.
#
# A continuación, el modelo se evalúa en un conjunto de datos de prueba (X_test e y_test). Las predicciones se obtienen con el método predict y se calcula la precisión (accuracy) utilizando metrics.accuracy_score. La precisión en el conjunto de datos de prueba se almacena en la variable acc_test y se imprime en pantalla.
#
# Finalmente, se evalúa el modelo en el conjunto de datos de entrenamiento (X_train_undersampled e y_train_undersampled) y se almacena la precisión en la variable acc_train, que también se imprime en pantalla.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
import sklearn.metrics as metrics

lambda_value = 1
model_logreg =  Pipeline([
                ('polynomial_features', PolynomialFeatures(degree=2)), #no cambiar
                ('scaler', StandardScaler()),
                ('logistic_regression', LogisticRegression(max_iter=20000, penalty='l2', C=1/lambda_value))
 ])



# training
model_logreg.fit(X_train_undersampled, y_train_undersampled)

# evaluation on test set
pred_test = model_logreg.predict(X_test)
acc_test = metrics.accuracy_score(y_test, pred_test)
print("Accuracy on test set Logistic Regression: ", acc_test)
# evaluation on training set
pred_train = model_logreg.predict(X_train_undersampled)
acc_train = metrics.accuracy_score(y_train_undersampled, pred_train)
print("Accuracy on training set Logistic Regression: ", acc_train)
# Out:
# Accuracy on test set Logistic Regression:  0.7338537970191625
# Accuracy on training set Logistic Regression:  0.7966555183946489

# %% [markdown]
# ## ✅ Actividad
#
# En esta actividad se debe obtener una gráfica cuyo eje x es el hiperparámetro de regularización lambda (variable lambda_value) y cuyo eje de las ordenadas es el accuracy. Su gráfica debe mostrar tanto el accuracy en el conjunto de entrenamiento como en el conjunto de validación. Use los siguientes valores (sugerencia) para lambda  [ 1e-4, 1e-3, 1e-2, 0.1, 1, 10, 100, 1e3, 1e4]. Haga la escala del eje x logarítmica para visualizar mejor sus resultados. Para esto, usted debe añadir plt.xscale('log') en su código al momento de graficar. Observe el siguiente ejemplo de gráfica con escala logarítmica en el eje x. Analice el gráfico y determine cuál cree que sería el valor óptimo de lambda. Use GridSearchCV con k=5 folds. Finalmente, evalúe su modelo optimizado (i.e, el modelo con el lambda_value que produce el mejor desempeño en el conj. de validación) en el conjunto de test. Esta actividad puede **demorar en ejecutar**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some example data
x = np.logspace(0, 4, 100)
y = x ** 2

# Create the plot
plt.plot(x, y)
plt.xscale('log') # Set logarithmic scale on x-axis
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Logarithmic Scale on X-axis')
plt.ylim(0, 1000)
plt.show()
# Set limit for y-axis

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import numpy as np

# Crear pipeline
model_logreg = Pipeline(
    [
        ("polynomial_features", PolynomialFeatures(degree=2)),  # no cambiar
        ("scaler", StandardScaler()),
        ("logistic_regression", LogisticRegression(max_iter=50000, penalty="l2")),
    ]
)

# Definir la grilla de parámetros (C = 1 / lambda)
C = np.logspace(-4, 6, 100)
param_grid = {"logistic_regression__C": 1 / C}

# Inicializar GridSearchCV
grid_search = GridSearchCV(
    model_logreg,
    param_grid,
    cv=5,  # k-fold cross-validation
    scoring="accuracy",  # puedes cambiarlo a 'neg_mean_squared_error' si lo prefieres
    return_train_score=True,
    verbose=4,
)

# Entrenar
grid_search.fit(X_train_undersampled, y_train_undersampled)

# Evaluación en conjunto de prueba
best_model = grid_search.best_estimator_
results = grid_search.cv_results_
train_result = results["mean_train_score"]
test_result = results["mean_test_score"]
best_alpha = 1 / best_model.named_steps["logistic_regression"].C
pred_test = best_model.predict(X_test)
acc_test = metrics.accuracy_score(y_test, pred_test)
print("Accuracy on test set Logistic Regression:", acc_test)

# Evaluación en conjunto de entrenamiento
pred_train = best_model.predict(X_train_undersampled)
acc_train = metrics.accuracy_score(y_train_undersampled, pred_train)
print("Accuracy on training set Logistic Regression:", acc_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END logistic_regression__C=10000.0;, score=(train=0.812, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=10000.0;, score=(train=0.805, test=0.756) total time=   1.7s
# [CV 3/5] END logistic_regression__C=10000.0;, score=(train=0.810, test=0.746) total time=   1.0s
# [CV 4/5] END logistic_regression__C=10000.0;, score=(train=0.811, test=0.729) total time=   1.0s
# [CV 5/5] END logistic_regression__C=10000.0;, score=(train=0.809, test=0.729) total time=   1.0s
# [CV 1/5] END logistic_regression__C=7924.82898353917;, score=(train=0.813, test=0.727) total time=   0.9s
# [CV 2/5] END logistic_regression__C=7924.82898353917;, score=(train=0.804, test=0.758) total time=   1.7s
# [CV 3/5] END logistic_regression__C=7924.82898353917;, score=(train=0.811, test=0.746) total time=   0.9s
# [CV 4/5] END logistic_regression__C=7924.82898353917;, score=(train=0.814, test=0.732) total time=   1.3s
# [CV 5/5] END logistic_regression__C=7924.82898353917;, score=(train=0.809, test=0.729) total time=   1.1s
# [CV 1/5] END logistic_regression__C=6280.2914418342525;, score=(train=0.811, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=6280.2914418342525;, score=(train=0.804, test=0.758) total time=   1.7s
# [CV 3/5] END logistic_regression__C=6280.2914418342525;, score=(train=0.810, test=0.746) total time=   1.0s
# [CV 4/5] END logistic_regression__C=6280.2914418342525;, score=(train=0.814, test=0.732) total time=   1.3s
# [CV 5/5] END logistic_regression__C=6280.2914418342525;, score=(train=0.809, test=0.731) total time=   1.1s
# [CV 1/5] END logistic_regression__C=4977.023564332109;, score=(train=0.812, test=0.731) total time=   1.1s
# [CV 2/5] END logistic_regression__C=4977.023564332109;, score=(train=0.804, test=0.759) total time=   1.6s
# [CV 3/5] END logistic_regression__C=4977.023564332109;, score=(train=0.810, test=0.746) total time=   1.2s
# [CV 4/5] END logistic_regression__C=4977.023564332109;, score=(train=0.814, test=0.731) total time=   1.4s
# [CV 5/5] END logistic_regression__C=4977.023564332109;, score=(train=0.807, test=0.731) total time=   1.0s
# [CV 1/5] END logistic_regression__C=3944.2060594376558;, score=(train=0.811, test=0.731) total time=   1.0s
# [CV 2/5] END logistic_regression__C=3944.2060594376558;, score=(train=0.805, test=0.756) total time=   1.7s
# [CV 3/5] END logistic_regression__C=3944.2060594376558;, score=(train=0.811, test=0.746) total time=   1.2s
# [CV 4/5] END logistic_regression__C=3944.2060594376558;, score=(train=0.812, test=0.736) total time=   1.0s
# [CV 5/5] END logistic_regression__C=3944.2060594376558;, score=(train=0.809, test=0.729) total time=   1.0s
# [CV 1/5] END logistic_regression__C=3125.7158496882353;, score=(train=0.813, test=0.731) total time=   1.0s
# [CV 2/5] END logistic_regression__C=3125.7158496882353;, score=(train=0.804, test=0.751) total time=   1.4s
# [CV 3/5] END logistic_regression__C=3125.7158496882353;, score=(train=0.810, test=0.746) total time=   1.1s
# [CV 4/5] END logistic_regression__C=3125.7158496882353;, score=(train=0.813, test=0.734) total time=   1.3s
# [CV 5/5] END logistic_regression__C=3125.7158496882353;, score=(train=0.810, test=0.729) total time=   1.1s
# [CV 1/5] END logistic_regression__C=2477.0763559917114;, score=(train=0.811, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=2477.0763559917114;, score=(train=0.804, test=0.756) total time=   1.2s
# [CV 3/5] END logistic_regression__C=2477.0763559917114;, score=(train=0.809, test=0.747) total time=   1.2s
# [CV 4/5] END logistic_regression__C=2477.0763559917114;, score=(train=0.813, test=0.732) total time=   1.1s
# [CV 5/5] END logistic_regression__C=2477.0763559917114;, score=(train=0.809, test=0.727) total time=   1.1s
# [CV 1/5] END logistic_regression__C=1963.0406500402705;, score=(train=0.812, test=0.732) total time=   1.1s
# [CV 2/5] END logistic_regression__C=1963.0406500402705;, score=(train=0.804, test=0.756) total time=   1.3s
# [CV 3/5] END logistic_regression__C=1963.0406500402705;, score=(train=0.810, test=0.746) total time=   1.3s
# [CV 4/5] END logistic_regression__C=1963.0406500402705;, score=(train=0.814, test=0.734) total time=   1.5s
# [CV 5/5] END logistic_regression__C=1963.0406500402705;, score=(train=0.810, test=0.729) total time=   1.1s
# [CV 1/5] END logistic_regression__C=1555.6761439304723;, score=(train=0.813, test=0.731) total time=   1.0s
# [CV 2/5] END logistic_regression__C=1555.6761439304723;, score=(train=0.804, test=0.758) total time=   1.7s
# [CV 3/5] END logistic_regression__C=1555.6761439304723;, score=(train=0.810, test=0.744) total time=   1.0s
# [CV 4/5] END logistic_regression__C=1555.6761439304723;, score=(train=0.813, test=0.734) total time=   0.9s
# [CV 5/5] END logistic_regression__C=1555.6761439304723;, score=(train=0.811, test=0.726) total time=   1.1s
# [CV 1/5] END logistic_regression__C=1232.8467394420659;, score=(train=0.812, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=1232.8467394420659;, score=(train=0.804, test=0.756) total time=   1.1s
# [CV 3/5] END logistic_regression__C=1232.8467394420659;, score=(train=0.810, test=0.747) total time=   0.8s
# [CV 4/5] END logistic_regression__C=1232.8467394420659;, score=(train=0.814, test=0.734) total time=   1.3s
# [CV 5/5] END logistic_regression__C=1232.8467394420659;, score=(train=0.810, test=0.732) total time=   1.0s
# [CV 1/5] END logistic_regression__C=977.0099572992247;, score=(train=0.812, test=0.729) total time=   0.9s
# [CV 2/5] END logistic_regression__C=977.0099572992247;, score=(train=0.804, test=0.756) total time=   1.1s
# [CV 3/5] END logistic_regression__C=977.0099572992247;, score=(train=0.811, test=0.746) total time=   0.9s
# [CV 4/5] END logistic_regression__C=977.0099572992247;, score=(train=0.814, test=0.732) total time=   1.0s
# [CV 5/5] END logistic_regression__C=977.0099572992247;, score=(train=0.809, test=0.731) total time=   1.0s
# [CV 1/5] END logistic_regression__C=774.263682681127;, score=(train=0.812, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=774.263682681127;, score=(train=0.806, test=0.763) total time=   0.9s
# [CV 3/5] END logistic_regression__C=774.263682681127;, score=(train=0.810, test=0.744) total time=   1.0s
# [CV 4/5] END logistic_regression__C=774.263682681127;, score=(train=0.812, test=0.734) total time=   0.9s
# [CV 5/5] END logistic_regression__C=774.263682681127;, score=(train=0.810, test=0.729) total time=   1.1s
# [CV 1/5] END logistic_regression__C=613.5907273413176;, score=(train=0.813, test=0.732) total time=   0.9s
# [CV 2/5] END logistic_regression__C=613.5907273413176;, score=(train=0.804, test=0.758) total time=   1.2s
# [CV 3/5] END logistic_regression__C=613.5907273413176;, score=(train=0.810, test=0.749) total time=   0.8s
# [CV 4/5] END logistic_regression__C=613.5907273413176;, score=(train=0.814, test=0.734) total time=   1.1s
# [CV 5/5] END logistic_regression__C=613.5907273413176;, score=(train=0.809, test=0.729) total time=   1.1s
# [CV 1/5] END logistic_regression__C=486.2601580065353;, score=(train=0.813, test=0.732) total time=   1.0s
# [CV 2/5] END logistic_regression__C=486.2601580065353;, score=(train=0.804, test=0.758) total time=   1.5s
# [CV 3/5] END logistic_regression__C=486.2601580065353;, score=(train=0.808, test=0.746) total time=   1.0s
# [CV 4/5] END logistic_regression__C=486.2601580065353;, score=(train=0.813, test=0.734) total time=   1.0s
# [CV 5/5] END logistic_regression__C=486.2601580065353;, score=(train=0.809, test=0.732) total time=   1.0s
# [CV 1/5] END logistic_regression__C=385.3528593710528;, score=(train=0.813, test=0.729) total time=   1.1s
# [CV 2/5] END logistic_regression__C=385.3528593710528;, score=(train=0.806, test=0.758) total time=   1.1s
# [CV 3/5] END logistic_regression__C=385.3528593710528;, score=(train=0.812, test=0.746) total time=   1.0s
# [CV 4/5] END logistic_regression__C=385.3528593710528;, score=(train=0.814, test=0.734) total time=   1.0s
# [CV 5/5] END logistic_regression__C=385.3528593710528;, score=(train=0.809, test=0.732) total time=   1.0s
# [CV 1/5] END logistic_regression__C=305.3855508833415;, score=(train=0.811, test=0.731) total time=   1.0s
# [CV 2/5] END logistic_regression__C=305.3855508833415;, score=(train=0.804, test=0.759) total time=   1.2s
# [CV 3/5] END logistic_regression__C=305.3855508833415;, score=(train=0.807, test=0.742) total time=   1.0s
# [CV 4/5] END logistic_regression__C=305.3855508833415;, score=(train=0.811, test=0.734) total time=   1.0s
# [CV 5/5] END logistic_regression__C=305.3855508833415;, score=(train=0.807, test=0.731) total time=   1.0s
# [CV 1/5] END logistic_regression__C=242.01282647943836;, score=(train=0.811, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=242.01282647943836;, score=(train=0.804, test=0.756) total time=   1.2s
# [CV 3/5] END logistic_regression__C=242.01282647943836;, score=(train=0.808, test=0.744) total time=   1.1s
# [CV 4/5] END logistic_regression__C=242.01282647943836;, score=(train=0.811, test=0.729) total time=   0.9s
# [CV 5/5] END logistic_regression__C=242.01282647943836;, score=(train=0.808, test=0.727) total time=   1.0s
# [CV 1/5] END logistic_regression__C=191.79102616724887;, score=(train=0.811, test=0.732) total time=   0.8s
# [CV 2/5] END logistic_regression__C=191.79102616724887;, score=(train=0.805, test=0.759) total time=   0.8s
# [CV 3/5] END logistic_regression__C=191.79102616724887;, score=(train=0.809, test=0.746) total time=   1.1s
# [CV 4/5] END logistic_regression__C=191.79102616724887;, score=(train=0.813, test=0.731) total time=   0.9s
# [CV 5/5] END logistic_regression__C=191.79102616724887;, score=(train=0.809, test=0.727) total time=   1.0s
# [CV 1/5] END logistic_regression__C=151.99110829529332;, score=(train=0.811, test=0.732) total time=   0.7s
# [CV 2/5] END logistic_regression__C=151.99110829529332;, score=(train=0.805, test=0.763) total time=   1.0s
# [CV 3/5] END logistic_regression__C=151.99110829529332;, score=(train=0.808, test=0.749) total time=   0.8s
# [CV 4/5] END logistic_regression__C=151.99110829529332;, score=(train=0.812, test=0.732) total time=   0.7s
# [CV 5/5] END logistic_regression__C=151.99110829529332;, score=(train=0.809, test=0.727) total time=   0.9s
# [CV 1/5] END logistic_regression__C=120.45035402587824;, score=(train=0.811, test=0.729) total time=   0.8s
# [CV 2/5] END logistic_regression__C=120.45035402587824;, score=(train=0.804, test=0.763) total time=   0.8s
# [CV 3/5] END logistic_regression__C=120.45035402587824;, score=(train=0.807, test=0.751) total time=   0.7s
# [CV 4/5] END logistic_regression__C=120.45035402587824;, score=(train=0.811, test=0.734) total time=   0.8s
# [CV 5/5] END logistic_regression__C=120.45035402587824;, score=(train=0.806, test=0.729) total time=   1.0s
# [CV 1/5] END logistic_regression__C=95.45484566618337;, score=(train=0.809, test=0.734) total time=   0.8s
# [CV 2/5] END logistic_regression__C=95.45484566618337;, score=(train=0.804, test=0.758) total time=   0.8s
# [CV 3/5] END logistic_regression__C=95.45484566618337;, score=(train=0.808, test=0.749) total time=   0.7s
# [CV 4/5] END logistic_regression__C=95.45484566618337;, score=(train=0.812, test=0.731) total time=   0.9s
# [CV 5/5] END logistic_regression__C=95.45484566618337;, score=(train=0.807, test=0.729) total time=   0.8s
# [CV 1/5] END logistic_regression__C=75.64633275546291;, score=(train=0.810, test=0.726) total time=   0.8s
# [CV 2/5] END logistic_regression__C=75.64633275546291;, score=(train=0.804, test=0.763) total time=   0.9s
# [CV 3/5] END logistic_regression__C=75.64633275546291;, score=(train=0.808, test=0.751) total time=   0.8s
# [CV 4/5] END logistic_regression__C=75.64633275546291;, score=(train=0.809, test=0.732) total time=   0.8s
# [CV 5/5] END logistic_regression__C=75.64633275546291;, score=(train=0.805, test=0.731) total time=   1.1s
# [CV 1/5] END logistic_regression__C=59.94842503189408;, score=(train=0.811, test=0.731) total time=   0.9s
# [CV 2/5] END logistic_regression__C=59.94842503189408;, score=(train=0.803, test=0.758) total time=   0.9s
# [CV 3/5] END logistic_regression__C=59.94842503189408;, score=(train=0.808, test=0.753) total time=   0.7s
# [CV 4/5] END logistic_regression__C=59.94842503189408;, score=(train=0.811, test=0.732) total time=   0.7s
# [CV 5/5] END logistic_regression__C=59.94842503189408;, score=(train=0.806, test=0.729) total time=   0.8s
# [CV 1/5] END logistic_regression__C=47.508101621027976;, score=(train=0.809, test=0.734) total time=   0.7s
# [CV 2/5] END logistic_regression__C=47.508101621027976;, score=(train=0.803, test=0.764) total time=   0.8s
# [CV 3/5] END logistic_regression__C=47.508101621027976;, score=(train=0.809, test=0.747) total time=   0.7s
# [CV 4/5] END logistic_regression__C=47.508101621027976;, score=(train=0.810, test=0.732) total time=   0.7s
# [CV 5/5] END logistic_regression__C=47.508101621027976;, score=(train=0.808, test=0.727) total time=   0.8s
# [CV 1/5] END logistic_regression__C=37.64935806792467;, score=(train=0.810, test=0.732) total time=   0.7s
# [CV 2/5] END logistic_regression__C=37.64935806792467;, score=(train=0.803, test=0.763) total time=   0.8s
# [CV 3/5] END logistic_regression__C=37.64935806792467;, score=(train=0.810, test=0.751) total time=   0.7s
# [CV 4/5] END logistic_regression__C=37.64935806792467;, score=(train=0.812, test=0.732) total time=   0.7s
# [CV 5/5] END logistic_regression__C=37.64935806792467;, score=(train=0.806, test=0.729) total time=   0.7s
# [CV 1/5] END logistic_regression__C=29.8364724028334;, score=(train=0.810, test=0.734) total time=   0.6s
# [CV 2/5] END logistic_regression__C=29.8364724028334;, score=(train=0.802, test=0.764) total time=   0.7s
# [CV 3/5] END logistic_regression__C=29.8364724028334;, score=(train=0.810, test=0.754) total time=   0.7s
# [CV 4/5] END logistic_regression__C=29.8364724028334;, score=(train=0.813, test=0.732) total time=   0.8s
# [CV 5/5] END logistic_regression__C=29.8364724028334;, score=(train=0.804, test=0.729) total time=   0.7s
# [CV 1/5] END logistic_regression__C=23.644894126454073;, score=(train=0.810, test=0.736) total time=   0.7s
# [CV 2/5] END logistic_regression__C=23.644894126454073;, score=(train=0.802, test=0.759) total time=   0.7s
# [CV 3/5] END logistic_regression__C=23.644894126454073;, score=(train=0.809, test=0.756) total time=   0.6s
# [CV 4/5] END logistic_regression__C=23.644894126454073;, score=(train=0.811, test=0.729) total time=   0.6s
# [CV 5/5] END logistic_regression__C=23.644894126454073;, score=(train=0.804, test=0.727) total time=   0.6s
# [CV 1/5] END logistic_regression__C=18.73817422860385;, score=(train=0.810, test=0.734) total time=   0.5s
# [CV 2/5] END logistic_regression__C=18.73817422860385;, score=(train=0.801, test=0.766) total time=   0.6s
# [CV 3/5] END logistic_regression__C=18.73817422860385;, score=(train=0.808, test=0.756) total time=   0.5s
# [CV 4/5] END logistic_regression__C=18.73817422860385;, score=(train=0.810, test=0.732) total time=   0.5s
# [CV 5/5] END logistic_regression__C=18.73817422860385;, score=(train=0.806, test=0.731) total time=   0.5s
# [CV 1/5] END logistic_regression__C=14.84968262254465;, score=(train=0.810, test=0.739) total time=   0.5s
# [CV 2/5] END logistic_regression__C=14.84968262254465;, score=(train=0.801, test=0.764) total time=   0.5s
# [CV 3/5] END logistic_regression__C=14.84968262254465;, score=(train=0.808, test=0.754) total time=   0.5s
# [CV 4/5] END logistic_regression__C=14.84968262254465;, score=(train=0.811, test=0.731) total time=   0.5s
# [CV 5/5] END logistic_regression__C=14.84968262254465;, score=(train=0.806, test=0.732) total time=   0.5s
# [CV 1/5] END logistic_regression__C=11.768119524349991;, score=(train=0.809, test=0.741) total time=   0.4s
# [CV 2/5] END logistic_regression__C=11.768119524349991;, score=(train=0.799, test=0.763) total time=   0.4s
# [CV 3/5] END logistic_regression__C=11.768119524349991;, score=(train=0.808, test=0.753) total time=   0.4s
# [CV 4/5] END logistic_regression__C=11.768119524349991;, score=(train=0.810, test=0.731) total time=   0.4s
# [CV 5/5] END logistic_regression__C=11.768119524349991;, score=(train=0.806, test=0.732) total time=   0.5s
# [CV 1/5] END logistic_regression__C=9.3260334688322;, score=(train=0.809, test=0.739) total time=   0.4s
# [CV 2/5] END logistic_regression__C=9.3260334688322;, score=(train=0.799, test=0.768) total time=   0.4s
# [CV 3/5] END logistic_regression__C=9.3260334688322;, score=(train=0.809, test=0.753) total time=   0.4s
# [CV 4/5] END logistic_regression__C=9.3260334688322;, score=(train=0.809, test=0.727) total time=   0.4s
# [CV 5/5] END logistic_regression__C=9.3260334688322;, score=(train=0.806, test=0.732) total time=   0.5s
# [CV 1/5] END logistic_regression__C=7.390722033525783;, score=(train=0.809, test=0.741) total time=   0.4s
# [CV 2/5] END logistic_regression__C=7.390722033525783;, score=(train=0.798, test=0.768) total time=   0.4s
# [CV 3/5] END logistic_regression__C=7.390722033525783;, score=(train=0.809, test=0.749) total time=   0.4s
# [CV 4/5] END logistic_regression__C=7.390722033525783;, score=(train=0.809, test=0.729) total time=   0.4s
# [CV 5/5] END logistic_regression__C=7.390722033525783;, score=(train=0.805, test=0.731) total time=   0.4s
# [CV 1/5] END logistic_regression__C=5.857020818056667;, score=(train=0.809, test=0.736) total time=   0.3s
# [CV 2/5] END logistic_regression__C=5.857020818056667;, score=(train=0.797, test=0.768) total time=   0.3s
# [CV 3/5] END logistic_regression__C=5.857020818056667;, score=(train=0.810, test=0.749) total time=   0.3s
# [CV 4/5] END logistic_regression__C=5.857020818056667;, score=(train=0.809, test=0.732) total time=   0.6s
# [CV 5/5] END logistic_regression__C=5.857020818056667;, score=(train=0.806, test=0.732) total time=   0.4s
# [CV 1/5] END logistic_regression__C=4.6415888336127775;, score=(train=0.808, test=0.739) total time=   0.4s
# [CV 2/5] END logistic_regression__C=4.6415888336127775;, score=(train=0.797, test=0.768) total time=   0.4s
# [CV 3/5] END logistic_regression__C=4.6415888336127775;, score=(train=0.809, test=0.749) total time=   0.4s
# [CV 4/5] END logistic_regression__C=4.6415888336127775;, score=(train=0.808, test=0.727) total time=   0.3s
# [CV 5/5] END logistic_regression__C=4.6415888336127775;, score=(train=0.804, test=0.732) total time=   0.4s
# [CV 1/5] END logistic_regression__C=3.6783797718286344;, score=(train=0.809, test=0.739) total time=   0.3s
# [CV 2/5] END logistic_regression__C=3.6783797718286344;, score=(train=0.798, test=0.768) total time=   0.3s
# [CV 3/5] END logistic_regression__C=3.6783797718286344;, score=(train=0.810, test=0.751) total time=   0.3s
# [CV 4/5] END logistic_regression__C=3.6783797718286344;, score=(train=0.808, test=0.729) total time=   0.3s
# [CV 5/5] END logistic_regression__C=3.6783797718286344;, score=(train=0.804, test=0.731) total time=   0.4s
# [CV 1/5] END logistic_regression__C=2.9150530628251756;, score=(train=0.809, test=0.741) total time=   0.3s
# [CV 2/5] END logistic_regression__C=2.9150530628251756;, score=(train=0.800, test=0.768) total time=   0.3s
# [CV 3/5] END logistic_regression__C=2.9150530628251756;, score=(train=0.809, test=0.751) total time=   0.4s
# [CV 4/5] END logistic_regression__C=2.9150530628251756;, score=(train=0.808, test=0.731) total time=   0.3s
# [CV 5/5] END logistic_regression__C=2.9150530628251756;, score=(train=0.803, test=0.732) total time=   0.4s
# [CV 1/5] END logistic_regression__C=2.31012970008316;, score=(train=0.808, test=0.741) total time=   0.2s
# [CV 2/5] END logistic_regression__C=2.31012970008316;, score=(train=0.800, test=0.766) total time=   0.3s
# [CV 3/5] END logistic_regression__C=2.31012970008316;, score=(train=0.809, test=0.753) total time=   0.3s
# [CV 4/5] END logistic_regression__C=2.31012970008316;, score=(train=0.808, test=0.731) total time=   0.3s
# [CV 5/5] END logistic_regression__C=2.31012970008316;, score=(train=0.804, test=0.732) total time=   0.3s
# [CV 1/5] END logistic_regression__C=1.8307382802953678;, score=(train=0.809, test=0.741) total time=   0.3s
# [CV 2/5] END logistic_regression__C=1.8307382802953678;, score=(train=0.800, test=0.768) total time=   0.2s
# [CV 3/5] END logistic_regression__C=1.8307382802953678;, score=(train=0.808, test=0.754) total time=   0.2s
# [CV 4/5] END logistic_regression__C=1.8307382802953678;, score=(train=0.807, test=0.731) total time=   0.2s
# [CV 5/5] END logistic_regression__C=1.8307382802953678;, score=(train=0.804, test=0.734) total time=   0.2s
# [CV 1/5] END logistic_regression__C=1.4508287784959404;, score=(train=0.810, test=0.741) total time=   0.2s
# [CV 2/5] END logistic_regression__C=1.4508287784959404;, score=(train=0.801, test=0.771) total time=   0.2s
# [CV 3/5] END logistic_regression__C=1.4508287784959404;, score=(train=0.809, test=0.751) total time=   0.2s
# [CV 4/5] END logistic_regression__C=1.4508287784959404;, score=(train=0.806, test=0.732) total time=   0.2s
# [CV 5/5] END logistic_regression__C=1.4508287784959404;, score=(train=0.806, test=0.734) total time=   0.2s
# [CV 1/5] END logistic_regression__C=1.1497569953977356;, score=(train=0.810, test=0.744) total time=   0.2s
# [CV 2/5] END logistic_regression__C=1.1497569953977356;, score=(train=0.801, test=0.771) total time=   0.2s
# [CV 3/5] END logistic_regression__C=1.1497569953977356;, score=(train=0.809, test=0.754) total time=   0.2s
# [CV 4/5] END logistic_regression__C=1.1497569953977356;, score=(train=0.806, test=0.732) total time=   0.2s
# [CV 5/5] END logistic_regression__C=1.1497569953977356;, score=(train=0.804, test=0.729) total time=   0.2s
# [CV 1/5] END logistic_regression__C=0.9111627561154887;, score=(train=0.809, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.9111627561154887;, score=(train=0.801, test=0.773) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.9111627561154887;, score=(train=0.808, test=0.753) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.9111627561154887;, score=(train=0.807, test=0.732) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.9111627561154887;, score=(train=0.805, test=0.729) total time=   0.2s
# [CV 1/5] END logistic_regression__C=0.7220809018385471;, score=(train=0.809, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.7220809018385471;, score=(train=0.801, test=0.778) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.7220809018385471;, score=(train=0.808, test=0.751) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.7220809018385471;, score=(train=0.806, test=0.732) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.7220809018385471;, score=(train=0.804, test=0.731) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.572236765935022;, score=(train=0.808, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.572236765935022;, score=(train=0.800, test=0.779) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.572236765935022;, score=(train=0.808, test=0.753) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.572236765935022;, score=(train=0.809, test=0.729) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.572236765935022;, score=(train=0.804, test=0.731) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.45348785081285825;, score=(train=0.807, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.45348785081285825;, score=(train=0.799, test=0.776) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.45348785081285825;, score=(train=0.809, test=0.749) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.45348785081285825;, score=(train=0.810, test=0.731) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.45348785081285825;, score=(train=0.804, test=0.732) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.3593813663804626;, score=(train=0.807, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.3593813663804626;, score=(train=0.798, test=0.776) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.3593813663804626;, score=(train=0.807, test=0.749) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.3593813663804626;, score=(train=0.810, test=0.726) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.3593813663804626;, score=(train=0.805, test=0.732) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.2848035868435805;, score=(train=0.806, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.2848035868435805;, score=(train=0.799, test=0.776) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.2848035868435805;, score=(train=0.807, test=0.749) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.2848035868435805;, score=(train=0.809, test=0.727) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.2848035868435805;, score=(train=0.805, test=0.731) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.22570197196339215;, score=(train=0.806, test=0.742) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.22570197196339215;, score=(train=0.798, test=0.778) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.22570197196339215;, score=(train=0.805, test=0.751) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.22570197196339215;, score=(train=0.809, test=0.726) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.22570197196339215;, score=(train=0.805, test=0.729) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.17886495290574353;, score=(train=0.804, test=0.744) total time=   0.1s
# [CV 2/5] END logistic_regression__C=0.17886495290574353;, score=(train=0.799, test=0.779) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.17886495290574353;, score=(train=0.806, test=0.753) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.17886495290574353;, score=(train=0.807, test=0.726) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.17886495290574353;, score=(train=0.805, test=0.731) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.14174741629268048;, score=(train=0.804, test=0.746) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.14174741629268048;, score=(train=0.797, test=0.778) total time=   0.1s
# [CV 3/5] END logistic_regression__C=0.14174741629268048;, score=(train=0.803, test=0.754) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.14174741629268048;, score=(train=0.807, test=0.724) total time=   0.1s
# [CV 5/5] END logistic_regression__C=0.14174741629268048;, score=(train=0.805, test=0.731) total time=   0.1s
# [CV 1/5] END logistic_regression__C=0.11233240329780267;, score=(train=0.803, test=0.746) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.11233240329780267;, score=(train=0.797, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.11233240329780267;, score=(train=0.804, test=0.758) total time=   0.1s
# [CV 4/5] END logistic_regression__C=0.11233240329780267;, score=(train=0.807, test=0.724) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.11233240329780267;, score=(train=0.805, test=0.731) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.08902150854450393;, score=(train=0.801, test=0.742) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.08902150854450393;, score=(train=0.796, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.08902150854450393;, score=(train=0.805, test=0.754) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.08902150854450393;, score=(train=0.806, test=0.724) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.08902150854450393;, score=(train=0.804, test=0.731) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.07054802310718646;, score=(train=0.801, test=0.742) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.07054802310718646;, score=(train=0.796, test=0.778) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.07054802310718646;, score=(train=0.805, test=0.754) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.07054802310718646;, score=(train=0.806, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.07054802310718646;, score=(train=0.804, test=0.736) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.05590810182512222;, score=(train=0.801, test=0.744) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.05590810182512222;, score=(train=0.798, test=0.778) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.05590810182512222;, score=(train=0.804, test=0.758) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.05590810182512222;, score=(train=0.803, test=0.726) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.05590810182512222;, score=(train=0.804, test=0.731) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.044306214575838776;, score=(train=0.800, test=0.744) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.044306214575838776;, score=(train=0.796, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.044306214575838776;, score=(train=0.804, test=0.753) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.044306214575838776;, score=(train=0.802, test=0.724) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.044306214575838776;, score=(train=0.804, test=0.731) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.03511191734215134;, score=(train=0.799, test=0.747) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.03511191734215134;, score=(train=0.795, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.03511191734215134;, score=(train=0.804, test=0.753) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.03511191734215134;, score=(train=0.803, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.03511191734215134;, score=(train=0.805, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.027825594022071257;, score=(train=0.798, test=0.749) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.027825594022071257;, score=(train=0.793, test=0.778) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.027825594022071257;, score=(train=0.804, test=0.753) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.027825594022071257;, score=(train=0.802, test=0.732) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.027825594022071257;, score=(train=0.802, test=0.727) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.022051307399030457;, score=(train=0.798, test=0.749) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.022051307399030457;, score=(train=0.791, test=0.783) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.022051307399030457;, score=(train=0.804, test=0.759) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.022051307399030457;, score=(train=0.801, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.022051307399030457;, score=(train=0.800, test=0.732) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.017475284000076828;, score=(train=0.798, test=0.749) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.017475284000076828;, score=(train=0.791, test=0.784) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.017475284000076828;, score=(train=0.801, test=0.763) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.017475284000076828;, score=(train=0.798, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.017475284000076828;, score=(train=0.800, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.013848863713938746;, score=(train=0.796, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.013848863713938746;, score=(train=0.791, test=0.784) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.013848863713938746;, score=(train=0.799, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.013848863713938746;, score=(train=0.797, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.013848863713938746;, score=(train=0.799, test=0.736) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.010974987654930567;, score=(train=0.795, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.010974987654930567;, score=(train=0.788, test=0.784) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.010974987654930567;, score=(train=0.797, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.010974987654930567;, score=(train=0.798, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.010974987654930567;, score=(train=0.799, test=0.739) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.008697490026177835;, score=(train=0.796, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.008697490026177835;, score=(train=0.789, test=0.788) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.008697490026177835;, score=(train=0.796, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.008697490026177835;, score=(train=0.798, test=0.734) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.008697490026177835;, score=(train=0.799, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.006892612104349696;, score=(train=0.797, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.006892612104349696;, score=(train=0.787, test=0.789) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.006892612104349696;, score=(train=0.794, test=0.769) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.006892612104349696;, score=(train=0.798, test=0.739) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.006892612104349696;, score=(train=0.797, test=0.744) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.005462277217684348;, score=(train=0.796, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.005462277217684348;, score=(train=0.788, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.005462277217684348;, score=(train=0.791, test=0.774) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.005462277217684348;, score=(train=0.797, test=0.742) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.005462277217684348;, score=(train=0.795, test=0.751) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.004328761281083062;, score=(train=0.797, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.004328761281083062;, score=(train=0.788, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.004328761281083062;, score=(train=0.790, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.004328761281083062;, score=(train=0.795, test=0.742) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.004328761281083062;, score=(train=0.793, test=0.749) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0034304692863149195;, score=(train=0.796, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0034304692863149195;, score=(train=0.786, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0034304692863149195;, score=(train=0.786, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0034304692863149195;, score=(train=0.797, test=0.742) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0034304692863149195;, score=(train=0.793, test=0.753) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.00271858824273294;, score=(train=0.796, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.00271858824273294;, score=(train=0.786, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.00271858824273294;, score=(train=0.788, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.00271858824273294;, score=(train=0.795, test=0.739) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.00271858824273294;, score=(train=0.793, test=0.751) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0021544346900318825;, score=(train=0.794, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0021544346900318825;, score=(train=0.784, test=0.796) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0021544346900318825;, score=(train=0.788, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0021544346900318825;, score=(train=0.793, test=0.737) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0021544346900318825;, score=(train=0.790, test=0.747) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0017073526474706922;, score=(train=0.793, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0017073526474706922;, score=(train=0.781, test=0.796) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0017073526474706922;, score=(train=0.788, test=0.759) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0017073526474706922;, score=(train=0.790, test=0.737) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0017073526474706922;, score=(train=0.791, test=0.753) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0013530477745798076;, score=(train=0.790, test=0.764) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0013530477745798076;, score=(train=0.776, test=0.794) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0013530477745798076;, score=(train=0.786, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0013530477745798076;, score=(train=0.789, test=0.739) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0013530477745798076;, score=(train=0.788, test=0.758) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0010722672220103231;, score=(train=0.785, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0010722672220103231;, score=(train=0.775, test=0.798) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0010722672220103231;, score=(train=0.786, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0010722672220103231;, score=(train=0.786, test=0.737) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0010722672220103231;, score=(train=0.786, test=0.754) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0008497534359086439;, score=(train=0.782, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0008497534359086439;, score=(train=0.773, test=0.798) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0008497534359086439;, score=(train=0.782, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0008497534359086439;, score=(train=0.784, test=0.739) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0008497534359086439;, score=(train=0.785, test=0.749) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0006734150657750829;, score=(train=0.778, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0006734150657750829;, score=(train=0.770, test=0.796) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0006734150657750829;, score=(train=0.779, test=0.769) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0006734150657750829;, score=(train=0.781, test=0.747) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0006734150657750829;, score=(train=0.782, test=0.747) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0005336699231206312;, score=(train=0.777, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0005336699231206312;, score=(train=0.765, test=0.798) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0005336699231206312;, score=(train=0.779, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0005336699231206312;, score=(train=0.777, test=0.747) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0005336699231206312;, score=(train=0.779, test=0.746) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.00042292428743894984;, score=(train=0.775, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.00042292428743894984;, score=(train=0.764, test=0.794) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.00042292428743894984;, score=(train=0.775, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.00042292428743894984;, score=(train=0.777, test=0.751) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.00042292428743894984;, score=(train=0.779, test=0.746) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0003351602650938841;, score=(train=0.773, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0003351602650938841;, score=(train=0.763, test=0.794) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0003351602650938841;, score=(train=0.770, test=0.771) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0003351602650938841;, score=(train=0.775, test=0.754) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0003351602650938841;, score=(train=0.776, test=0.744) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0002656087782946689;, score=(train=0.772, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0002656087782946689;, score=(train=0.764, test=0.794) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0002656087782946689;, score=(train=0.767, test=0.773) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0002656087782946689;, score=(train=0.775, test=0.754) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0002656087782946689;, score=(train=0.775, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.00021049041445120217;, score=(train=0.771, test=0.766) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.00021049041445120217;, score=(train=0.763, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.00021049041445120217;, score=(train=0.766, test=0.773) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.00021049041445120217;, score=(train=0.771, test=0.751) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.00021049041445120217;, score=(train=0.773, test=0.742) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.0001668100537200059;, score=(train=0.770, test=0.764) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.0001668100537200059;, score=(train=0.761, test=0.793) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.0001668100537200059;, score=(train=0.764, test=0.771) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.0001668100537200059;, score=(train=0.774, test=0.749) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.0001668100537200059;, score=(train=0.771, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.00013219411484660288;, score=(train=0.766, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.00013219411484660288;, score=(train=0.759, test=0.791) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.00013219411484660288;, score=(train=0.764, test=0.773) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.00013219411484660288;, score=(train=0.773, test=0.744) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.00013219411484660288;, score=(train=0.771, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=0.00010476157527896662;, score=(train=0.764, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=0.00010476157527896662;, score=(train=0.757, test=0.786) total time=   0.0s
# [CV 3/5] END logistic_regression__C=0.00010476157527896662;, score=(train=0.764, test=0.774) total time=   0.0s
# [CV 4/5] END logistic_regression__C=0.00010476157527896662;, score=(train=0.770, test=0.741) total time=   0.0s
# [CV 5/5] END logistic_regression__C=0.00010476157527896662;, score=(train=0.768, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=8.302175681319735e-05;, score=(train=0.762, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=8.302175681319735e-05;, score=(train=0.755, test=0.783) total time=   0.0s
# [CV 3/5] END logistic_regression__C=8.302175681319735e-05;, score=(train=0.762, test=0.769) total time=   0.0s
# [CV 4/5] END logistic_regression__C=8.302175681319735e-05;, score=(train=0.766, test=0.732) total time=   0.0s
# [CV 5/5] END logistic_regression__C=8.302175681319735e-05;, score=(train=0.767, test=0.741) total time=   0.0s
# [CV 1/5] END logistic_regression__C=6.579332246575683e-05;, score=(train=0.761, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=6.579332246575683e-05;, score=(train=0.755, test=0.783) total time=   0.0s
# [CV 3/5] END logistic_regression__C=6.579332246575683e-05;, score=(train=0.760, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=6.579332246575683e-05;, score=(train=0.765, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=6.579332246575683e-05;, score=(train=0.765, test=0.737) total time=   0.0s
# [CV 1/5] END logistic_regression__C=5.214008287999695e-05;, score=(train=0.758, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=5.214008287999695e-05;, score=(train=0.753, test=0.781) total time=   0.0s
# [CV 3/5] END logistic_regression__C=5.214008287999695e-05;, score=(train=0.757, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=5.214008287999695e-05;, score=(train=0.763, test=0.729) total time=   0.0s
# [CV 5/5] END logistic_regression__C=5.214008287999695e-05;, score=(train=0.762, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=4.1320124001153344e-05;, score=(train=0.754, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=4.1320124001153344e-05;, score=(train=0.752, test=0.779) total time=   0.0s
# [CV 3/5] END logistic_regression__C=4.1320124001153344e-05;, score=(train=0.757, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=4.1320124001153344e-05;, score=(train=0.762, test=0.729) total time=   0.0s
# [CV 5/5] END logistic_regression__C=4.1320124001153344e-05;, score=(train=0.759, test=0.732) total time=   0.0s
# [CV 1/5] END logistic_regression__C=3.274549162877732e-05;, score=(train=0.753, test=0.761) total time=   0.0s
# [CV 2/5] END logistic_regression__C=3.274549162877732e-05;, score=(train=0.750, test=0.781) total time=   0.0s
# [CV 3/5] END logistic_regression__C=3.274549162877732e-05;, score=(train=0.754, test=0.769) total time=   0.0s
# [CV 4/5] END logistic_regression__C=3.274549162877732e-05;, score=(train=0.760, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=3.274549162877732e-05;, score=(train=0.758, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=2.595024211399732e-05;, score=(train=0.751, test=0.763) total time=   0.0s
# [CV 2/5] END logistic_regression__C=2.595024211399732e-05;, score=(train=0.750, test=0.778) total time=   0.0s
# [CV 3/5] END logistic_regression__C=2.595024211399732e-05;, score=(train=0.753, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=2.595024211399732e-05;, score=(train=0.758, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=2.595024211399732e-05;, score=(train=0.757, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=2.0565123083486515e-05;, score=(train=0.750, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=2.0565123083486515e-05;, score=(train=0.749, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=2.0565123083486515e-05;, score=(train=0.753, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=2.0565123083486515e-05;, score=(train=0.757, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=2.0565123083486515e-05;, score=(train=0.758, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1.629750834620647e-05;, score=(train=0.751, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1.629750834620647e-05;, score=(train=0.748, test=0.776) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1.629750834620647e-05;, score=(train=0.751, test=0.763) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1.629750834620647e-05;, score=(train=0.755, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1.629750834620647e-05;, score=(train=0.757, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1.2915496650148825e-05;, score=(train=0.751, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1.2915496650148825e-05;, score=(train=0.748, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1.2915496650148825e-05;, score=(train=0.750, test=0.763) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1.2915496650148825e-05;, score=(train=0.755, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1.2915496650148825e-05;, score=(train=0.755, test=0.736) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1.023531021899027e-05;, score=(train=0.751, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1.023531021899027e-05;, score=(train=0.749, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1.023531021899027e-05;, score=(train=0.749, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1.023531021899027e-05;, score=(train=0.757, test=0.731) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1.023531021899027e-05;, score=(train=0.756, test=0.732) total time=   0.0s
# [CV 1/5] END logistic_regression__C=8.11130830789689e-06;, score=(train=0.748, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=8.11130830789689e-06;, score=(train=0.747, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=8.11130830789689e-06;, score=(train=0.748, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=8.11130830789689e-06;, score=(train=0.758, test=0.732) total time=   0.0s
# [CV 5/5] END logistic_regression__C=8.11130830789689e-06;, score=(train=0.757, test=0.734) total time=   0.0s
# [CV 1/5] END logistic_regression__C=6.428073117284319e-06;, score=(train=0.749, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=6.428073117284319e-06;, score=(train=0.747, test=0.774) total time=   0.0s
# [CV 3/5] END logistic_regression__C=6.428073117284319e-06;, score=(train=0.748, test=0.768) total time=   0.0s
# [CV 4/5] END logistic_regression__C=6.428073117284319e-06;, score=(train=0.758, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=6.428073117284319e-06;, score=(train=0.755, test=0.731) total time=   0.0s
# [CV 1/5] END logistic_regression__C=5.094138014816386e-06;, score=(train=0.750, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=5.094138014816386e-06;, score=(train=0.747, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=5.094138014816386e-06;, score=(train=0.747, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=5.094138014816386e-06;, score=(train=0.757, test=0.726) total time=   0.0s
# [CV 5/5] END logistic_regression__C=5.094138014816386e-06;, score=(train=0.755, test=0.726) total time=   0.0s
# [CV 1/5] END logistic_regression__C=4.037017258596549e-06;, score=(train=0.750, test=0.754) total time=   0.0s
# [CV 2/5] END logistic_regression__C=4.037017258596549e-06;, score=(train=0.746, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=4.037017258596549e-06;, score=(train=0.746, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=4.037017258596549e-06;, score=(train=0.755, test=0.726) total time=   0.0s
# [CV 5/5] END logistic_regression__C=4.037017258596549e-06;, score=(train=0.756, test=0.727) total time=   0.0s
# [CV 1/5] END logistic_regression__C=3.1992671377973842e-06;, score=(train=0.750, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=3.1992671377973842e-06;, score=(train=0.745, test=0.773) total time=   0.0s
# [CV 3/5] END logistic_regression__C=3.1992671377973842e-06;, score=(train=0.746, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=3.1992671377973842e-06;, score=(train=0.755, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=3.1992671377973842e-06;, score=(train=0.756, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=2.5353644939701167e-06;, score=(train=0.749, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=2.5353644939701167e-06;, score=(train=0.745, test=0.771) total time=   0.0s
# [CV 3/5] END logistic_regression__C=2.5353644939701167e-06;, score=(train=0.747, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=2.5353644939701167e-06;, score=(train=0.753, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=2.5353644939701167e-06;, score=(train=0.755, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=2.009233002565046e-06;, score=(train=0.748, test=0.756) total time=   0.0s
# [CV 2/5] END logistic_regression__C=2.009233002565046e-06;, score=(train=0.746, test=0.771) total time=   0.0s
# [CV 3/5] END logistic_regression__C=2.009233002565046e-06;, score=(train=0.747, test=0.766) total time=   0.0s
# [CV 4/5] END logistic_regression__C=2.009233002565046e-06;, score=(train=0.753, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=2.009233002565046e-06;, score=(train=0.755, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1.592282793341094e-06;, score=(train=0.747, test=0.758) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1.592282793341094e-06;, score=(train=0.746, test=0.771) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1.592282793341094e-06;, score=(train=0.746, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1.592282793341094e-06;, score=(train=0.753, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1.592282793341094e-06;, score=(train=0.755, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1.2618568830660185e-06;, score=(train=0.746, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1.2618568830660185e-06;, score=(train=0.746, test=0.771) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1.2618568830660185e-06;, score=(train=0.747, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1.2618568830660185e-06;, score=(train=0.754, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1.2618568830660185e-06;, score=(train=0.754, test=0.729) total time=   0.0s
# [CV 1/5] END logistic_regression__C=1e-06;, score=(train=0.746, test=0.759) total time=   0.0s
# [CV 2/5] END logistic_regression__C=1e-06;, score=(train=0.745, test=0.771) total time=   0.0s
# [CV 3/5] END logistic_regression__C=1e-06;, score=(train=0.746, test=0.764) total time=   0.0s
# [CV 4/5] END logistic_regression__C=1e-06;, score=(train=0.753, test=0.727) total time=   0.0s
# [CV 5/5] END logistic_regression__C=1e-06;, score=(train=0.754, test=0.726) total time=   0.0s
# Accuracy on test set Logistic Regression: 0.7395315826827538
# Accuracy on training set Logistic Regression: 0.7712374581939799

# %%
plt.plot(C, test_result, label="Test Accuracy")
plt.plot(C, train_result, label="Train Accuracy")
plt.xscale("log")  # Set logarithmic scale on x-axis
plt.xlabel("alpha (1/lambda)")
plt.ylabel("Accuracy")
plt.title("Logarithmic Scale on X-axis")
plt.axvline(x=best_alpha, color='r', linestyle='--', label=f'Best model at $\lambda$: {best_alpha:.2e}')
plt.legend()
plt.show()

# %% [markdown]
# # ✅ Conclusiones
# Concluya su trabajo con sus principales observaciones obtenidas de los resultados de sus experimentos
